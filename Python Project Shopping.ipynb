# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
shopdata = pd.read_csv("/Users/macbookpro/Downloads/WhatsgoodlyData-6.csv")

# %%
shopdata.describe()
# Out:
#              Count   Percentage
# count  1450.000000  1450.000000
# mean     35.013793     0.199313
# std      95.055604     0.274989
# min       0.000000     0.000000
# 25%       0.000000     0.000000
# 50%       1.000000     0.063500
# 75%      20.000000     0.323750
# max     947.000000     1.000000

# %%
shopdata.isna()
# Out:
#       Question  Segment Type  Segment Description  Answer  Count  Percentage
# 0        False         False                False   False  False       False
# 1        False         False                False   False  False       False
# 2        False         False                False   False  False       False
# 3        False         False                False   False  False       False
# 4        False         False                False   False  False       False
# ...        ...           ...                  ...     ...    ...         ...
# 1445     False         False                False   False  False       False
# 1446     False         False                False   False  False       False
# 1447     False         False                False   False  False       False
# 1448     False         False                False   False  False       False
# 1449     False         False                False   False  False       False
#
# [1450 rows x 6 columns]

# %%
shopdata.dropna(inplace = True)
print(shopdata.isnull().sum())
print(shopdata.info)
# Out:
# Question               0
# Segment Type           0
# Segment Description    0
# Answer                 0
# Count                  0
# Percentage             0
# dtype: int64
# <bound method DataFrame.info of                                                Question Segment Type  \
# 0     What social platform has influenced your onlin...       Mobile
# 1     What social platform has influenced your onlin...       Mobile
# 2     What social platform has influenced your onlin...       Mobile
# 3     What social platform has influenced your onlin...       Mobile
# 4     What social platform has influenced your onlin...       Mobile
# ...                                                 ...          ...
# 1445  What social platform has influenced your onlin...       Custom
# 1446  What social platform has influenced your onlin...       Custom
# 1447  What social platform has influenced your onlin...       Custom
# 1448  What social platform has influenced your onlin...       Custom
# ...

# %%
shopdata.head(10)
# Out:
#                                             Question Segment Type  \
# 0  What social platform has influenced your onlin...       Mobile
# 1  What social platform has influenced your onlin...       Mobile
# 2  What social platform has influenced your onlin...       Mobile
# 3  What social platform has influenced your onlin...       Mobile
# 4  What social platform has influenced your onlin...       Mobile
# 5  What social platform has influenced your onlin...          Web
# 6  What social platform has influenced your onlin...          Web
# 7  What social platform has influenced your onlin...          Web
# 8  What social platform has influenced your onlin...          Web
# 9  What social platform has influenced your onlin...          Web
#
#   Segment Description     Answer  Count  Percentage
# 0      Global results   Facebook    548       0.205
# 1      Global results  Instagram    916       0.342
# 2      Global results   Snapchat     86       0.032
# ...

# %%
sns.heatmap(shopdata.corr(), linewidths = 5, linecolor = "white")
# Out:
# <AxesSubplot:>

# %%
social_media = shopdata['Answer']

# %%
 Social_Media = ['Facebook','Instagram','Snapchat', 'Twitter', 'Other']
Counts = [548, 916, 86, 179, 947]

plt.figure(1)
x = range(5)
plt.xticks(x, Social_Media)
sns.barplot(x = Social_Media, y = Counts)
plt.title("Mobile Shopping Across the Globe")
plt.xlabel("Social Media")
plt.ylabel("Votes")
# Out:
# Text(0, 0.5, 'Votes')

# %%
y = np.array([548, 916, 86, 179, 947])
mylabels = ["Facebook", "Instagram", "Snapchat", "Twitter", "Other"]

plt.pie(y, labels = mylabels)
plt.legend(title = "Social Media:")
plt.legend(loc='center')
plt.title("Global Social Media Shopping Platforms")
plt.show()

# %%
y = np.array([548, 916, 86, 179, 947])
platforms = ["Facebook", "Instagram", "Snapchat", "Twitter", "Other"]
myexplode = [0, 0, 0, 0, 0.2]

plt.pie(y, labels = platforms, explode = myexplode)
plt.title("Global Social Media Shopping Platforms")
plt.show()

# %%
y = np.array([548, 916, 86, 179])
platforms = ["Facebook", "Instagram", "Snapchat", "Twitter"]

plt.pie(y, labels = platforms)
plt.title("Global Social Media Shopping Platforms")
plt.show()

# %%
y = np.array([222, 535, 29, 57, 271])
mylabels = ["Facebook", "Instagram", "Snapchat", "Twitter", "Other"]

plt.pie(y, labels = mylabels)
plt.title("Female Shopping Preference - Social Media Platforms")
plt.show()

# %%
y = np.array([326, 380, 56, 122, 678])
mylabels = ["Facebook", "Instagram", "Snapchat", "Twitter", "Other"]

plt.pie(y, labels = mylabels)
plt.title("Male Shopping Preference - Social Media Platforms")
plt.show()

# %%
Social_Media = ['Facebook','Instagram','Snapchat', 'Twitter']
Counts = [486, 729, 68, 131]

plt.figure(1)
x = range(4)
plt.xticks(x, Social_Media)
sns.barplot(x = Social_Media, y = Counts)
plt.title("Shopping on Social Media Platforms from University Students")
plt.xlabel("Social Media")
plt.ylabel("Votes")
# Out:
# Text(0, 0.5, 'Votes')
